# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
dataset=pd.read_csv("spotify_data.csv")

# %%
dataset.head()
# Out:
#          Date  Shape of You  Despacito  Something Just Like This  HUMBLE.  \
# 0  08-04-2017      12815920    6660608                   9334494  7280150
# 1  09-04-2017      11291392    5683746                   8077875  6396104
# 2  10-04-2017      11819128    5762588                   8678774  7162611
# 3  11-04-2017      11736951    5877897                   8591469  7468021
# 4  12-04-2017      11716914    6041766                   8590463  7495873
#
#    Unforgettable
# 0         308838
# 1         756145
# 2         954504
# 3         953037
# 4         972755

# %%
plt.figure(figsize=(14,7))
plt.title("Heat Map of Streaming of songs along 15 days")
sns.heatmap(data=dataset.iloc[:,1:],annot=True)
plt.show()

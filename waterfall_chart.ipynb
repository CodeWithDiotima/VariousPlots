# %%
import waterfall_chart

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams.update({'figure.figsize':(30,30), 'figure.dpi':100})

# %%
df = pd.read_csv(r"Salary_Data.csv")
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
df['change'] = [i - df['Salary'][0] for i in df['Salary']]

# %%
df
# Out:
#     YearsExperience    Salary   change
# 0               1.1   39343.0      0.0
# 1               1.3   46205.0   6862.0
# 2               1.5   37731.0  -1612.0
# 3               2.0   43525.0   4182.0
# 4               2.2   39891.0    548.0
# 5               2.9   56642.0  17299.0
# 6               3.0   60150.0  20807.0
# 7               3.2   54445.0  15102.0
# 8               3.2   64445.0  25102.0
# 9               3.7   57189.0  17846.0
# 10              3.9   63218.0  23875.0
# 11              4.0   55794.0  16451.0
# 12              4.0   56957.0  17614.0
# 13              4.1   57081.0  17738.0
# 14              4.5   61111.0  21768.0
# 15              4.9   67938.0  28595.0
# 16              5.1   66029.0  26686.0
# 17              5.3   83088.0  43745.0
# 18              5.9   81363.0  42020.0
# 19              6.0   93940.0  54597.0
# 20              6.8   91738.0  52395.0
# 21              7.1   98273.0  58930.0
# 22              7.9  101302.0  61959.0
# 23              8.2  113812.0  74469.0
# 24              8.7  109431.0  70088.0
# 25              9.0  105582.0  66239.0
# 26              9.5  116969.0  77626.0
# 27              9.6  112635.0  73292.0
# 28             10.3  122391.0  83048.0
# 29             10.5  121872.0  82529.0

# %%
waterfall_chart.plot(df['YearsExperience'],df['change'])
# Out:
# C:\Users\Diotima\anaconda3\lib\site-packages\waterfall_chart.py:71: FutureWarning: The behavior of `series[i:j]` with an integer-dtype index is deprecated. In a future version, this will be treated as *label-based* indexing, consistent with e.g. `series[i]` lookups. To retain the old behavior, use `series.iloc[i:j]`. To get the future behavior, use `series.loc[i:j]`.
#   step[1::3] = np.nan
# <module 'matplotlib.pyplot' from 'C:\\Users\\Diotima\\AppData\\Roaming\\Python\\Python39\\site-packages\\matplotlib\\pyplot.py'>
